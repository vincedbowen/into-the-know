# %%
import urllib3
#for https certificates
import certifi
from dotenv import load_dotenv
import os
import json
import pandas as pd
import numpy as np
import matplotlib.pylab as plt

# %%
load_dotenv()
stravaAuthorization = os.environ['stravaAuth']
#Get request to strava API
http = urllib3.PoolManager(
    cert_reqs="CERT_REQUIRED",
    ca_certs=certifi.where()
)
response = http.request(
    "GET",
    "https://www.strava.com/api/v3/athlete/activities",
    headers={
        'Authorization': 'Bearer ' + stravaAuthorization
    },
    timeout = 4,
    retries = 4
)
myData = json.loads(response.data)

# %%
print(myData)
# Out:
# [{'resource_state': 2, 'athlete': {'id': 119427941, 'resource_state': 1}, 'name': 'Kitt sprint and zone 2 part of flagstaff ', 'distance': 21348.7, 'moving_time': 4224, 'elapsed_time': 4301, 'total_elevation_gain': 494.0, 'type': 'Ride', 'sport_type': 'Ride', 'workout_type': 10, 'id': 9555896680, 'start_date': '2023-07-31T12:52:56Z', 'start_date_local': '2023-07-31T06:52:56Z', 'timezone': '(GMT-07:00) America/Denver', 'utc_offset': -21600.0, 'location_city': None, 'location_state': None, 'location_country': 'United States', 'achievement_count': 4, 'kudos_count': 0, 'comment_count': 0, 'athlete_count': 1, 'photo_count': 0, 'map': {'id': 'a9555896680', 'summary_polyline': 'uffsFxcpaSfD_@zAe@bHGp@JjAvAZAHuAEsANu@XObCATSPaOJ]r@q@JkBPu@tAuAb@kBfEO?_NNu@t@k@p@Cl@Lz@t@x@HXIfAoA~AF~@e@xA?dAd@zAm@Na@C_EcBwFMqAVoBjA{@tCMdAPfAbAd@bBPDGe@s@{AiAs@aCUqB\\m@l@Uf@Kl@AfAXzAnArDFbLFTxCBpFiC~AeBDi@YcB`@BXt@lAz@RfBHbL?~dCLhAx@hDT|BjApD?l@ST}@DeD}@_ABcAt@s@jAmDrAaClDyANuBk@aA?k@bAU`BYX{@]yBCSgA]Uc@XQdAcCzBSh@At@Pp@fA~@|Bl@fDN|AhBx@^h@At@c@bAgC^kBb@[dFQ`Bf@nApAFZIJq@_AeAa@c@`@Sl@o@vEq@WSk@Gy@S]WCSXLdBx@xA|@x@z@K|@m@v@kARMLLEh@cBnAa@~@DfG^d@hBjAnAZr@d@v@tA|A|AD^]?_A_AqBsAeCYsDf@}@e@sAaB[?G\\hDxEzBC|AF`B`CZnABv@M~ABp@hAxAZ`A^|BDvAZtA~AfBv@xBvClFrAdBT`AF~BVx@~AtBrC|GK_A_B{Dk@]yAUcA}@cAoCwAoAUsBWo@qC_DkDcCqBuCw@e@{AG_BpAwA@eA`A[?kBiD_@kB[BGd@d@R`A|BfA`B^EbAu@v@Lb@Iv@cA^SxA?l@VfBrCfCdBlE|EXxBzAdBr@|BxAvAhBPGk@w@}@Wk@UuC]uAsBuCwB{Dq@oBsA}AUm@_@oDe@qBYs@}@kAGq@RiCKy@o@eBy@oAe@Y}@KqBRe@SmCyDHSRCx@jAr@l@tEUnBX`CjBl@z@RJVKEq@iA{@iBsCcBo@cCaBEuGRk@lByAHe@Ma@o@@gArAcAp@yAaAq@yAGeAVMLR?x@Pn@l@b@\\AXW^cEX}@`@Od@NbAxATQ@YSe@oAoA_AYcG?a@Pi@t@kA|Dq@l@k@ByAq@cAkAuCSmCo@m@e@YgADw@Xk@nCiB~DLnATd@o@NyAd@y@z@ErBp@|AMrB}Cp@e@fC{@z@oAr@i@|ACfDz@b@EZ[Fy@gAcDg@aDe@kBWyB?ia@G_@uBBaNFsh@?}BBQi@A}AFyHIyCBqPIsFAyH}@aCo@k@qH?', 'resource_state': 2}, 'trainer': False, 'commute': False, 'manual': False, 'private': False, 'visibility': 'everyone', 'flagged': False, 'gear_id': 'b12783989', 'start_latlng': [40.02, -105.27], 'end_latlng': [40.01, -105.27], 'average_speed': 5.054, 'max_speed': 15.562, 'average_cadence': 69.1, 'average_temp': 21, 'average_watts': 130.3, 'max_watts': 867, 'weighted_average_watts': 167, 'kilojoules': 550.4, 'device_watts': True, 'has_heartrate': True, 'average_heartrate': 140.1, 'max_heartrate': 180.0, 'heartrate_opt_out': False, 'display_hide_heartrate_option': True, 'elev_high': 1980.6, 'elev_low': 1534.0, 'upload_id': 10247047134, 'upload_id_str': '10247047134', 'external_id': '2023_07_31_06_52_56.fit', 'from_accepted_tag': False, 'pr_count': 2, 'total_photo_count': 0, 'has_kudoed': False, 'suffer_score': 62.0}, {'resource_state': 2, 'athlete': {'id': 119427941, 'resource_state': 1}, 'name': 'Fun morning cruising around', 'distance': 41230.7, 'moving_time': 6728, 'elapsed_time': 6861, 'total_elevation_gain': 758.0, 'type': 'Ride', 'sport_type': 'Ride', 'workout_type': 10, 'id': 9544994907, 'start_date': '2023-07-29T15:33:52Z', 'start_date_local': '2023-07-29T09:33:52Z', 'timezone': '(GMT-07:00) America/Denver', 'utc_offset': -21600.0, 'location_city': None, 'location_state': None, 'location_country': 'United States', 'achievement_count': 91, 'kudos_count': 0, 'comment_count': 0, 'athlete_count': 1, 'photo_count': 0, 'map': {'id': 'a9544994907', 'summary_polyline': 'uvfsFl`paScCP_Ex@_CsSa@sAib@fK_An@kCzEw@F{nCd@sq@UmFXMl@Hx]IfB}CG}Bl@cAnAu@tCwG@_@f@@dLRtGKrNoBvGaIfTQ~AOjJhC~Qu@zKe@|CaElJoBdDeF|A{Dk@g@T@\\hBvAb@`AMfCDp@fCK`BbBb@~@p@dG_ArE[XiCGwB^q@\\^A\\a@yMbGeFvDeDi@iC?oJhAiJDcIlA{EHoCt@yAl@qBrBm@hAu@vCiElJgAbBcDvC_BXaIcAoA`@i@dAQhJsBpJMhDw@dDe@bF_BvILhOWfF_@`BcAjBkAbAiCt@sBjDSfAC|Do@fDfAzDJjAIpBoAxH}BrDcAlJPjChA~Et@~JWxAkAzDo@dGa@zIb@`@dBD`BlBpG`LzAvDRjAQz@u@iAi@WkGe@wCvCsG`Co@nACh@k@OuAaBkDkKoB{DcBcB{F{C}EqJuEkD[y@U}Bm@gA{EPg@_@iA}Ce@e@wDyAkCDaCmNeAuAeE_D{AcGw@}AeA]yFHkCbAm@?aBeB{CoAYe@Au@`@yBpBiG\\aGn@k@nBVf@YRaAUcDLiBf@aAtEaFRuB_@mJ`@aCvAkCTwAc@cDg@{@uBgBeAkCGiKlAeGG_AY_@w@CkCvC_AVaAI{GkCw@oBn@aQ{@oHl@sDD_Cf@eE{AsHTwGY}CmAcEcAwAGa@Pi@lCaChBsCNy@DcEz ...

# %%
data_dict = dict()
for i in range(len(myData)):
    if myData[i]['device_watts'] == True:
        if myData[i]['id'] not in data_dict.keys():
            data_dict[myData[i]['id']] = {'Date' : myData[i]['start_date'], 'Average Watts' : myData[i]['average_watts'], 'Maximum Watts' : myData[i]['max_watts']}
        else:
            print("err")
df = pd.DataFrame.from_dict(data_dict, orient='index')
print(df)
# Out:
#                             Date  Average Watts  Maximum Watts
# 9555896680  2023-07-31T12:52:56Z          130.3            867
# 9544994907  2023-07-29T15:33:52Z          154.2            817
# 9532188166  2023-07-27T15:12:43Z          131.9            466
# 9512850430  2023-07-24T14:25:01Z          151.0            613
# 9494209858  2023-07-21T13:02:27Z          149.8            836
# 9488528380  2023-07-20T14:16:20Z          158.1            720
# 9476242785  2023-07-18T16:43:42Z          137.4            665
# 9444220719  2023-07-13T14:08:49Z          142.7            655
# 9437726890  2023-07-12T14:07:29Z          155.4            586
# 9425224562  2023-07-10T13:30:36Z          135.5            601

# %%
fig, ax = plt.subplots(figsize=(12,6))
ax.plot(df['Average Watts'], color='red')

ax.set_title("Average and Maximum Watts over Time", fontsize=20)
ax.set_xlabel("Dates", fontsize=16)
ax.set_ylabel("Watts", fontsize=16)
# Out:
# Text(0, 0.5, 'Watts')
